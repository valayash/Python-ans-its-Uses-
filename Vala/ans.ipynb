# %%
from matplotlib import pyplot as plt
import numpy as np
x=np.arange(10)
plt.plot(x,x*x)
plt.show()

# %%
x = [7,8,9,11,5,4,3,4,2,3,4,34,34,34,4]
y = [45,5,2,34,4,2,2,5,3,5,5,54,4,87,67]
plt.plot(x, y, 'bo')

# %%
plt.figure(figsize=(7,7))
a=[34,34,4,45,21,43,78,65,3]
plt.pie(a)
plt.show()
